# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

img = mpimg.imread('/Users/sumitasok/arena/src/github.com/sumitasok/CarND-Behavioral-Cloning-P3/images/input/14691633-Left-traffic-route-only-direction-sign-turn-pointer-green-isolated-roadside-signage-perspective-whit-Stock-Photo.jpg')
plt.imshow(img)

# %%
# %matplotlib inline

plt.imshow(img)
plt.plot(840, 40, '.')
plt.plot(840, 350, '.')
plt.plot(100, 400, '.')
plt.plot(100, 200, '.')

# %%
from preprocessing import warp

def warp(img):
    src = np.float32([
        [840, 40],
        [840, 350],
        [100, 400],
        [100, 200]])

    dst = np.float32([
        [830, 200],
        [830, 400],
        [100, 400],
        [100, 200]])
    
    img_size = (img.shape[1], img.shape[0])
    
    Minv = cv2.getPerspectiveTransform(dst, src)
    
    M = cv2.getPerspectiveTransform(src, dst)
    
    warped = cv2.warpPerspective(img, M, img_size, flags=cv2.INTER_LINEAR)
    
    return warped


plt.imshow(warp(img))

# warped = warp(img, src_points ,dst_points)
