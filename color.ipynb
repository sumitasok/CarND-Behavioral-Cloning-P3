# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import numpy as np

# %matplotlib inline

# %%
img = mpimg.imread('images/input/signs_vehicles_xygrad.jpg')
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(20, 10))
ax1.imshow(img)
ax1.set_title('RGB', fontsize=20)
hls_img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
ax2.imshow(hls_img)
ax2.set_title('HLS', fontsize=20)
hsv_img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
ax3.imshow(hsv_img)
ax3.set_title('HSV', fontsize=20)

# %%
img = mpimg.imread('images/input/curved-lane.jpg')
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(20, 10))
ax1.imshow(img)
ax1.set_title('RGB', fontsize=20)
hls_img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
ax2.imshow(hls_img)
ax2.set_title('HLS', fontsize=20)
hsv_img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
ax3.imshow(hsv_img)
ax3.set_title('HSV', fontsize=20)

# %% [markdown]
# # RGB > Gray > HLS

# %%
img = mpimg.imread('images/input/curved-lane.jpg')
gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(20, 10))
ax1.imshow(img)
ax1.set_title('RGB', fontsize=20)
ax2.imshow(gray_img)
ax2.set_title('Gray', fontsize=20)

thresh = (180, 255)
binary = np.zeros_like(gray_img)
binary[(gray_img > thresh[0]) & (gray_img <= thresh[1])] = 1

ax3.imshow(binary)
ax3.set_title('thresh 180, 255', fontsize=30)

# %%
img = mpimg.imread('images/input/center_2017_07_21_15_14_11_115.jpg')
gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(20, 10))
ax1.imshow(img)
ax1.set_title('RGB', fontsize=20)
ax2.imshow(gray_img)
ax2.set_title('Gray', fontsize=20)

thresh = (180, 255)
binary = np.zeros_like(gray_img)
binary[(gray_img > thresh[0]) & (gray_img <= thresh[1])] = 1

ax3.imshow(binary)
ax3.set_title('thresh 180, 255', fontsize=30)

R = image[:,:,0]
G = image[:,:,1]
B = image[:,:,2]
thresh = (200, 255)
binary = np.zeros_like(R)
binary[(R > thresh[0]) & (R <= thresh[1])] = 1
ax4.imshow(binary)
ax4.set_title('red channel', fontsize=20)

# %% [markdown]
# #### RGB -> Gray -> threshold for no border road.

# %%
img = mpimg.imread('images/input/center_2017_07_21_15_14_25_438_no_border.jpg')
gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
f, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(20, 10))
ax1.imshow(img)
ax1.set_title('RGB', fontsize=20)
ax2.imshow(gray_img)
ax2.set_title('Gray', fontsize=20)

thresh = (180, 255)
binary = np.zeros_like(gray_img)
binary[(gray_img > thresh[0]) & (gray_img <= thresh[1])] = 1

ax3.imshow(binary)
ax3.set_title('thresh 180, 255', fontsize=30)

R = image[:,:,0]
G = image[:,:,1]
B = image[:,:,2]
thresh = (200, 255)
binary = np.zeros_like(R)
binary[(R > thresh[0]) & (R <= thresh[1])] = 1
ax4.imshow(binary)
ax4.set_title('red channel', fontsize=20)

hls = cv2.cvtColor(image, cv2.COLOR_RGB2HLS)
H = hls[:,:,0]
L = hls[:,:,1]
S = hls[:,:,2]
thresh = (90, 255)
binary = np.zeros_like(S)
binary[(S > thresh[0]) & (S <= thresh[1])] = 1
ax5.imshow(binary)
ax5.set_title('S channel', fontsize=20)

# %%
img = mpimg.imread('images/input/center_2017_07_21_15_14_45_326.jpg')
gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
f, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(20, 10))
ax1.imshow(img)
ax1.set_title('RGB', fontsize=20)
ax2.imshow(gray_img)
ax2.set_title('Gray', fontsize=20)

thresh = (180, 255)
binary = np.zeros_like(gray_img)
binary[(gray_img > thresh[0]) & (gray_img <= thresh[1])] = 1

ax3.imshow(binary)
ax3.set_title('thresh 180, 255', fontsize=30)

sobel_kernel = 5
sobelx = cv2.Sobel(gray_img, cv2.CV_64F, 1, 0, ksize=sobel_kernel)
sobely = cv2.Sobel(gray_img, cv2.CV_64F, 0, 1, ksize=sobel_kernel)

thresh_min = 100
thresh_min = 255
abs_sobel = np.absolute(sobely)
scaled_sobel = np.uint8(255*abs_sobel/np.max(abs_sobel))
# Apply lower and upper thresholds
thresh_min = 20
thresh_max = 100
# Create binary_output
sxbinary = np.zeros_like(scaled_sobel)
sxbinary[(scaled_sobel >= thresh_min) & (scaled_sobel <= thresh_max)] = 1

ax4.imshow(sxbinary)
ax4.set_title('scaled sobel', fontsize=30)
